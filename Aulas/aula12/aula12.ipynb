# %% [markdown]
# # Aula 12

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread('Figuras12/Fig_Erosion_Dilation_U8.bmp', cv2.IMREAD_GRAYSCALE)

# Define a kernel (structuring element)
kernel_size = 5
kernel = np.ones((kernel_size, kernel_size), np.uint8)

# Apply erosion
img_erosion = cv2.erode(img1, kernel, iterations=1)

# Apply dilation
img_dilation = cv2.dilate(img1, kernel, iterations=1)

# Plot the original, eroded and dilated images
plt.figure(figsize=(15, 5))

plt.subplot(131)
plt.imshow(img1, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(132)
plt.imshow(img_erosion, cmap='gray')
plt.title('Erosion')
plt.axis('off')

plt.subplot(133)
plt.imshow(img_dilation, cmap='gray')
plt.title('Dilation')
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
img2 = cv2.imread('Figuras12/Ovos1_u8.bmp', cv2.IMREAD_GRAYSCALE)


# Apply thresholding to get binary image
_, binary = cv2.threshold(img2, 180, 255, cv2.THRESH_BINARY)

# Find contours
contours, hierarchy = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Create a copy of the binary image to draw contours on (keeping it black and white)
img_contours = binary.copy()

# Draw all contours in white on the black and white image
cv2.drawContours(img_contours, contours, -1, 255, 2)

# Display the results
plt.figure(figsize=(15, 5))

plt.subplot(131)
plt.imshow(img2, cmap='gray')
plt.title('Original Image')
plt.axis('off')

plt.subplot(132)
plt.imshow(binary, cmap='gray')
plt.title('Binary Image')
plt.axis('off')

plt.subplot(133)
plt.imshow(img_contours, cmap='gray')
plt.title(f'Contours Found: {len(contours)}')
plt.axis('off')

plt.tight_layout()
plt.show()

print(f"Number of contours found: {len(contours)}")
# Out:
# Number of contours found: 236
